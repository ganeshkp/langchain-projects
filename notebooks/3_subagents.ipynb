# %%
import os

from dotenv import load_dotenv

load_dotenv(os.path.join("..", ".env"), override=True)

# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings(
    "ignore",
    message="LangSmith now uses UUID v7", 
    category=UserWarning,
)

# %% [markdown]
# ## Context Isolation: Sub-agents
#
# <img src="./assets/agent_header_subagent.png" width="800" style="display:block; margin-left:0;">
#
# Agent context can grow quickly as conversations progress, leading to several long context-related problems. A primary issue is context clash or confusion, where mixed objectives within the same context window can lead to suboptimal performance. [Context isolation](https://blog.langchain.com/context-engineering-for-agents/) provides an effective solution by delegating tasks to [specialized sub-agents](https://www.anthropic.com/engineering/multi-agent-research-system), each operating within their own isolated context window. This approach prevents context clashes, confusion, poisoning, and dilution while enabling focused, specialized task execution.
#
#
#
# ### Sub-agent delegation
# ![./assets/subagents.png](./assets/subagents.png)
#
# The primary insight is that we can create sub-agents with different tool sets tailored to specific tasks. Each sub-agent is stored in a registry dictionary with `subagent_type` as the key, allowing the main agent to delegate work through a `task(description, subagent_type)` tool call. The sub-agent operates in complete isolation from the parent's context, and its results are returned as a `ToolMessage` to the parent agent, maintaining clean separation of concerns.

# %% [markdown]
# <div style="background-color: #fff3b0; padding: 10px; border-radius: 4px;">
# <b>Note:</b>
# The <code>create_react_agent</code> was moved from the LangGraph library to the LangChain library and renamed to <code>create_agent</code> in the 1.0 code release post-filming. There are slight changes to the imports and code to accommodate this. The video may display the previous configuration.
# </div>

# %% [markdown]
# ## Step 1: Create Sub Agents
#
# Let's define how the user will specify sub agents
# ```python
# from typing_extensions import TypedDict
#
# class SubAgent(TypedDict):
#     """Configuration for a specialized sub-agent."""
#
#     name: str
#     description: str
#     prompt: str
#     tools: NotRequired[list[str]]
# ```
#
# We will use a list of these objects to create all the sub agents we have access to
#
# ```python
# agents: list[SubAgent] = ...
# subagents = {
#     agent['name']: create_react_agent(
#         model=model,
#         prompt=agent['prompt'],
#         tools = get_tools(agent['tools']),
#         ...
#     )
# }
# ```
#
# ## Step 2: Create a tool to use Sub Agents
#
# Logically, should look something like:
#
# ```python
# def task(
#     description: str  # The task the subagent should do
#     subagent_type: str  # Which subagent to use
# ):
#     # Create new messages to pass to subagent - should just be the description
#     # Call sub agent
#     # Update state with both the subagents response AND any changes to file system
# ```
#
# This ends up in full looking like:
#
# ```python
# @tool(description=TASK_DESCRIPTION_PREFIX.format(other_agents=other_agents_string))
# def task(
#     description: str,
#     subagent_type: str,
#     state: Annotated[DeepAgentState, InjectedState],
#     tool_call_id: Annotated[str, InjectedToolCallId],
# ):
#     """Delegate a task to a specialized sub-agent with isolated context.
#
#     This creates a fresh context for the sub-agent containing only the task description,
#     preventing context pollution from the parent agent's conversation history.
#     """
#     # Validate requested agent type exists
#     if subagent_type not in agents:
#         return f"Error: invoked agent of type {subagent_type}, the only allowed types are {[f'`{k}`' for k in agents]}"
#
#     # Get the requested sub-agent
#     sub_agent = agents[subagent_type]
#
#     # Create isolated context with only the task description
#     # This is the key to context isolation - no parent history
#     state["messages"] = [{"role": "user", "content": description}]
#
#     # Execute the sub-agent in isolation
#     result = sub_agent.invoke(state)
#
#     # Return results to parent agent via Command state update
#     return Command(
#         update={
#             "files": result.get("files", {}),  # Merge any file changes
#             "messages": [
#                 # Sub-agent result becomes a ToolMessage in parent context
#                 ToolMessage(
#                     result["messages"][-1].content, tool_call_id=tool_call_id
#                 )
#             ],
#         }
#     )
#
# return task
# ```

# %%
# %%writefile ../src/deep_agents_from_scratch/task_tool.py
"""Task delegation tools for context isolation through sub-agents.

This module provides the core infrastructure for creating and managing sub-agents
with isolated contexts. Sub-agents prevent context clash by operating with clean
context windows containing only their specific task description.
"""

from typing import Annotated, NotRequired
from typing_extensions import TypedDict

from langchain_core.messages import ToolMessage
from langchain_core.tools import BaseTool, InjectedToolCallId, tool
from langgraph.prebuilt import InjectedState  # updated 1.0
from langchain.agents import create_agent  # updated 1.0

from langgraph.types import Command

from deep_agents_from_scratch.prompts import TASK_DESCRIPTION_PREFIX
from deep_agents_from_scratch.state import DeepAgentState


class SubAgent(TypedDict):
    """Configuration for a specialized sub-agent."""

    name: str
    description: str
    prompt: str
    tools: NotRequired[list[str]]


def _create_task_tool(tools, subagents: list[SubAgent], model, state_schema):
    """Create a task delegation tool that enables context isolation through sub-agents.

    This function implements the core pattern for spawning specialized sub-agents with
    isolated contexts, preventing context clash and confusion in complex multi-step tasks.

    Args:
        tools: List of available tools that can be assigned to sub-agents
        subagents: List of specialized sub-agent configurations
        model: The language model to use for all agents
        state_schema: The state schema (typically DeepAgentState)

    Returns:
        A 'task' tool that can delegate work to specialized sub-agents
    """
    # Create agent registry
    agents = {}

    # Build tool name mapping for selective tool assignment
    tools_by_name = {}
    for tool_ in tools:
        if not isinstance(tool_, BaseTool):
            tool_ = tool(tool_)
        tools_by_name[tool_.name] = tool_

    # Create specialized sub-agents based on configurations
    for _agent in subagents:
        if "tools" in _agent:
            # Use specific tools if specified
            _tools = [tools_by_name[t] for t in _agent["tools"]]
        else:
            # Default to all tools
            _tools = tools
        agents[_agent["name"]] = create_agent(   # updated 1.0
            model, system_prompt=_agent["prompt"], tools=_tools, state_schema=state_schema
        )

    # Generate description of available sub-agents for the tool description
    other_agents_string = [
        f"- {_agent['name']}: {_agent['description']}" for _agent in subagents
    ]

    @tool(description=TASK_DESCRIPTION_PREFIX.format(other_agents=other_agents_string))
    def task(
        description: str,
        subagent_type: str,
        state: Annotated[DeepAgentState, InjectedState],
        tool_call_id: Annotated[str, InjectedToolCallId],
    ):
        """Delegate a task to a specialized sub-agent with isolated context.

        This creates a fresh context for the sub-agent containing only the task description,
        preventing context pollution from the parent agent's conversation history.
        """
        # Validate requested agent type exists
        if subagent_type not in agents:
            return f"Error: invoked agent of type {subagent_type}, the only allowed types are {[f'`{k}`' for k in agents]}"

        # Get the requested sub-agent
        sub_agent = agents[subagent_type]

        # Create isolated context with only the task description
        # This is the key to context isolation - no parent history
        state["messages"] = [{"role": "user", "content": description}]

        # Execute the sub-agent in isolation
        result = sub_agent.invoke(state)

        # Return results to parent agent via Command state update
        return Command(
            update={
                "files": result.get("files", {}),  # Merge any file changes
                "messages": [
                    # Sub-agent result becomes a ToolMessage in parent context
                    ToolMessage(
                        result["messages"][-1].content, tool_call_id=tool_call_id
                    )
                ],
            }
        )

    return task
# Out:
# Overwriting ../src/deep_agents_from_scratch/task_tool.py

# %% [markdown]
# Now, you have a routine that will generate sub-agents as tools. Now, you can define specific sub-agents and allow the system to call them with the `task` tool.
# Above, the `_create_task_tool` receives a list of type `SubAgent`. This list contains descriptions of the agents that are to be created.
#
# ```python
# class SubAgent(TypedDict):
#     """Configuration for a specialized sub-agent."""
#
#     name: str
#     description: str
#     prompt: str
#     tools: NotRequired[list[str]]
#
#
# def _create_task_tool(tools, subagents: list[SubAgent], model, state_schema):
#     """Create a task delegation tool that enables context isolation through sub-agents.
#
# ```
# The `SubAgent` class defines the unique information needed to satisfy the dual role of a sub-agent. Sub-agents act as both tools and agents.
#
# - **As tools**, they provide the supervisor agent with information about their capabilities and how they can be called.
# - **As agents**, they require a prompt that describes how to carry out their tasks, along with a set of tools targeted for those tasks.
#
# Below, you will create a research subagent. Its `description` informs the supervisor agent that a single task should be delegated to this sub-agent. The `SIMPLE_RESEARCH_INSTRUCTIONS` is a prompt that is used by the sub-agent to direct its research. In this example, it is brief, but for a general-purpose researcher, it could be much more detailed. The sub-agent is also supplied with a `web_search` tool to use during its research.
#
# ```python
# # Create research sub-agent
# research_sub_agent = {
#     "name": "research-agent",
#     "description": "Delegate research to the sub-agent researcher. Only give this researcher one topic at a time.",
#     "prompt": SIMPLE_RESEARCH_INSTRUCTIONS,
#     "tools": ["web_search"],
# }
# ```
#
# Note that the sub-agent receives a specific task, along with the necessary tools to complete it. It operates in its own context, limited to the single task description. This [context-engineering](https://blog.langchain.com/context-engineering-for-agents/) approach ensures that the subagent’s working context remains free of context clashes, confusion, poisoning, and dilution.
#
# The supervisor agent prompt must now include a descripition of how to invoke and use these sub-agents. This is shown below. Note the *Available Tools* description and the instructions to use parallel research where applicable.

# %%
from utils import show_prompt

from deep_agents_from_scratch.prompts import SUBAGENT_USAGE_INSTRUCTIONS

show_prompt(SUBAGENT_USAGE_INSTRUCTIONS)
# Out:
# ╭──────────────────────────────────────────────────── Prompt ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  You can delegate tasks to sub-agents.                                                                          │
# │                                                                                                                 │
# │  <Task>                                                                                                         │
# │  Your role is to coordinate research by delegating specific research tasks to sub-agents.                       │
# │  </Task>                                                                                                        │
# │                                                                                                                 │
# │  <Available Tools>                                                                                              │
# │  1. **task(description, subagent_type)**: Delegate research tasks to specialized sub-agents                     │
# │     - description: Clear, specific research question or task                                                    │
# │     - subagent_type: Type of agent to use (e.g., "research-agent")                                              │
# │  2. **think_tool(reflection)**: Reflect on the results of each delegated task and plan next steps.              │
# │     - reflection: Your detailed reflection on the results of the task and next steps.                           │
# │                                                                                                                 │
# │  **PARALLEL RESEARCH**: When you identify multiple independent research directions, make multiple **task**      │
# │  tool calls in a single response to enable parallel execution. Use at most {max_concurrent_research_units}      │
# │  parallel agents per iteration.                                                                                 │
# │  </Available Tools>                                                                                             │
# │                                                                                                                 │
# │  <Hard Limits>                                                                                                  │
# │  **Task Delegation Budgets** (Prevent excessive delegation):                                                    │
# │  - **Bias towards focused research** - Use single agent for simple questions, multiple only when clearly        │
# │  beneficial or when you have multiple independent research directions based on the user's request.              │
# │  - **Stop when adequate** - Don't over-research; stop when you have sufficient information                      │
# │  - **Limit iterations** - Stop after {max_researcher_iterations} task delegations if you haven't found          │
# │  adequate sources                                                                                               │
# │  </Hard Limits>                                                                                                 │
# │                                                                                                                 │
# │  <Scaling Rules>                                                                                                │
# │  **Simple fact-finding, lists, and rankings** can use a single sub-agent:                                       │
# │  - *Example*: "List the top 10 coffee shops in San Francisco" → Use 1 sub-agent, store in                       │
# │  `findings_coffee_shops.md`                                                                                     │
# │                                                                                                                 │
# │  **Comparisons** can use a sub-agent for each element of the comparison:                                        │
# │  - *Example*: "Compare OpenAI vs. Anthropic vs. DeepMind approaches to AI safety" → Use 3 sub-agents            │
# │  - Store findings in separate files: `findings_openai_safety.md`, `findings_anthropic_safety.md`,               │
# │  `findings_deepmind_safety.md`                                                                                  │
# │                                                                                                                 │
# │  **Multi-faceted research** can use parallel agents for different aspects:                                      │
# │  - *Example*: "Research renewable energy: costs, environmental impact, and adoption rates" → Use 3 sub-agents   │
# │  - Organize findings by aspect in separate files                                                                │
# │                                                                                                                 │
# │  **Important Reminders:**                                                                                       │
# │  - Each **task** call creates a dedicated research agent with isolated context                                  │
# │  - Sub-agents can't see each other's work - provide complete standalone instructions                            │
# │  - Use clear, specific language - avoid acronyms or abbreviations in task descriptions                          │
# │  </Scaling Rules>                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Let's now build a research system with a supervisor and sub-agents. This will just be a mock-up version with pre-defined search results to demonstrate how the pieces go together. In the next lesson, you will build a full-fledged research system.

# %%
from datetime import datetime

from IPython.display import Image, display
from langchain.chat_models import init_chat_model
from langchain_core.tools import tool
#from langgraph.prebuilt import create_react_agent
from langchain.agents import create_agent # updated in 1.0

from deep_agents_from_scratch.prompts import SUBAGENT_USAGE_INSTRUCTIONS
from deep_agents_from_scratch.state import DeepAgentState
from deep_agents_from_scratch.task_tool import _create_task_tool

# Limits
max_concurrent_research_units = 3
max_researcher_iterations = 3

# Mock search result
search_result = """The Model Context Protocol (MCP) is an open standard protocol developed 
by Anthropic to enable seamless integration between AI models and external systems like 
tools, databases, and other services. It acts as a standardized communication layer, 
allowing AI models to access and utilize data from various sources in a consistent and 
efficient manner. Essentially, MCP simplifies the process of connecting AI assistants 
to external services by providing a unified language for data exchange. """


# Mock search tool
@tool(parse_docstring=True)
def web_search(
    query: str,
):
    """Search the web for information on a specific topic.

    This tool performs web searches and returns relevant results
    for the given query. Use this when you need to gather information from
    the internet about any topic.

    Args:
        query: The search query string. Be specific and clear about what
               information you're looking for.

    Returns:
        Search results from the search engine.

    Example:
        web_search("machine learning applications in healthcare")
    """
    return search_result


# Add mock research instructions
SIMPLE_RESEARCH_INSTRUCTIONS = """You are a researcher. Research the topic provided to you. IMPORTANT: Just make a single call to the web_search tool and use the result provided by the tool to answer the provided topic."""

# Create research sub-agent
research_sub_agent = {
    "name": "research-agent",
    "description": "Delegate research to the sub-agent researcher. Only give this researcher one topic at a time.",
    "prompt": SIMPLE_RESEARCH_INSTRUCTIONS,
    "tools": ["web_search"],
}

# Create agent using create_react_agent directly
model = init_chat_model(model="anthropic:claude-sonnet-4-6", temperature=0.0)

# Tools for sub-agent
sub_agent_tools = [web_search]

# Create task tool to delegate tasks to sub-agents
task_tool = _create_task_tool(
    sub_agent_tools, [research_sub_agent], model, DeepAgentState
)

# Tools
delegation_tools = [task_tool]

# Create agent with system prompt
agent = create_agent(
    model,
    delegation_tools,
    system_prompt=SUBAGENT_USAGE_INSTRUCTIONS.format(
        max_concurrent_research_units=max_concurrent_research_units,
        max_researcher_iterations=max_researcher_iterations,
        date=datetime.now().strftime("%a %b %-d, %Y"),
    ),
    state_schema=DeepAgentState,
)

# Show the agent
display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# %%
from utils import format_messages

result = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Give me an overview of Model Context Protocol (MCP).",
            }
        ],
    }
)

format_messages(result["messages"])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Give me an overview of Model Context Protocol (MCP).                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 🔧 Tool Call: task                                                                                              │
# │    Args: {                                                                                                      │
# │   "description": "Research the Model Context Protocol (MCP): what it is, its purpose, how it works, its         │
# │ architecture, key components, use cases, who created it, and its significance in the AI/LLM ecosystem. Include  │
# │ any recent developments or adoption details.",                                                                  │
# │   "subagent_type": "research-agent"                                                                             │
# │ }                                                                                                               │
# │    ID: toolu_01Pt5m7JM6QB6K6YWdtCZda9                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── 🔧 Tool Output ─────────────────────────────────────────────────╮
# │ Based on the research gathered, here is a comprehensive deep-dive into the **Model Context Protocol (MCP)**:    │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ # 🔌 Model Context Protocol (MCP): A Comprehensive Research Report                                              │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 1. 📌 What Is MCP?                                                                                           │
# │                                                                                                                 │
# │ The **Model Context Protocol (MCP)** is an **open standard protocol** developed by **Anthropic** that enables   │
# │ seamless, standardized integration between AI models (like Large Language Models) and external systems —        │
# │ including tools, databases, APIs, file systems, and other services.                                             │
# │                                                                                                                 │
# │ Think of MCP as a **universal adapter or "USB-C port" for AI** — just as USB-C standardized how devices connect │
# │ to peripherals, MCP standardizes how AI models connect to the outside world. Instead of building one-off,       │
# │ custom integrations for every tool or data source, developers can use MCP as a **unified communication layer**  │
# │ that any compliant AI system can speak.                                                                         │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 2. 🎯 Purpose & Problem It Solves                                                                            │
# │                                                                                                                 │
# │ Before MCP, connecting an AI assistant to external tools (e.g., a database, a code editor, a web browser, or a  │
# │ calendar) required **custom, bespoke integrations** for every combination of AI model + tool. This created:     │
# │                                                                                                                 │
# │ - **Fragmentation**: Every AI provider had its own way of calling tools.                                        │
# │ - **Duplication of effort**: Developers had to rebuild integrations for each new model or platform.             │
# │ - **Inconsistency**: No standard way to pass context, invoke tools, or handle responses.                        │
# │ - **Scalability problems**: As the number of tools and models grew, the integration matrix became unmanageable  │
# │ (an "N×M problem").                                                                                             │
# │                                                                                                                 │
# │ **MCP solves this** by providing a single, open protocol so that:                                               │
# │ - Any MCP-compatible AI model can connect to **any MCP-compatible tool or data source**.                        │
# │ - Developers build an integration **once** and it works across all compliant systems.                           │
# │ - AI assistants can dynamically discover, access, and use external capabilities in a **consistent, safe, and    │
# │ efficient** manner.                                                                                             │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 3. 👤 Who Created It?                                                                                        │
# │                                                                                                                 │
# │ MCP was created and open-sourced by **Anthropic**, the AI safety company behind the **Claude** family of large  │
# │ language models. Anthropic released MCP as an **open standard** — meaning it is not proprietary to Claude or    │
# │ Anthropic's products — with the explicit goal of fostering **industry-wide adoption** across the entire AI      │
# │ ecosystem.                                                                                                      │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 4. ⚙️ How It Works                                                                                            │
# │                                                                                                                 │
# │ MCP operates as a **client-server communication protocol** built on top of **JSON-RPC** (a lightweight remote   │
# │ procedure call protocol using JSON). Here's the flow:                                                           │
# │                                                                                                                 │
# │ 1. **An AI model (or its host application)** wants to access an external resource or invoke a tool.             │
# │ 2. It sends a **structured JSON-RPC request** via the MCP protocol to an MCP Server.                            │
# │ 3. The **MCP Server** (which wraps the external tool/data source) processes the request and returns a           │
# │ **structured response**.                                                                                        │
# │ 4. The AI model receives the response and incorporates it into its context/reasoning.                           │
# │                                                                                                                 │
# │ ### Transport Layer                                                                                             │
# │ MCP supports multiple transport mechanisms:                                                                     │
# │ - **Standard I/O (stdio)**: For local processes (e.g., a local file system server).                             │
# │ - **HTTP with Server-Sent Events (SSE)**: For remote/networked servers.                                         │
# │                                                                                                                 │
# │ This flexibility allows MCP to work in both **local desktop environments** and **cloud-based deployments**.     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 5. 🏗️ Architecture                                                                                            │
# │                                                                                                                 │
# │ MCP follows a clean **three-tier architecture**:                                                                │
# │                                                                                                                 │
# │ ### 🖥️ 1. MCP Host                                                                                               │
# │ - The **AI application or agent** that the end user interacts with (e.g., Claude Desktop, an IDE plugin, a      │
# │ chatbot).                                                                                                       │
# │ - The Host contains or manages the LLM and initiates requests.                                                  │
# │ - It is responsible for **user interaction, security policies**, and orchestrating communication.               │
# │                                                                                                                 │
# │ ### 🔗 2. MCP Client                                                                                            │
# │ - A component **embedded within the Host** that manages the protocol-level communication.                       │
# │ - It maintains a **1:1 connection** with an MCP Server.                                                         │
# │ - Handles the JSON-RPC message formatting, session management, and capability negotiation.                      │
# │                                                                                                                 │
# │ ### 🛠️ 3. MCP Server                                                                                             │
# │ - A **lightweight service** that exposes specific capabilities (tools, data, prompts) to the AI via the MCP     │
# │ protocol.                                                                                                       │
# │ - Servers can be local (running on the user's machine) or remote (cloud-hosted).                                │
# │ - Examples: a GitHub MCP server, a PostgreSQL MCP server, a web search MCP server.                              │
# │                                                                                                                 │
# │ ```                                                                                                             │
# │ ┌─────────────────────────────────────┐                                                                         │
# │ │           MCP HOST                  │                                                                         │
# │ │  (e.g., Claude Desktop, AI Agent)   │                                                                         │
# │ │                                     │                                                                         │
# │ │   ┌─────────────┐                   │                                                                         │
# │ │   │  MCP Client │◄──────────────────┼──► MCP Server A (e.g., File System)                                     │
# │ │   └─────────────┘                   │                                                                         │
# │ │   ┌─────────────┐                   │                                                                         │
# │ │   │  MCP Client │◄──────────────────┼──► MCP Server B (e.g., GitHub)                                          │
# │ │   └─────────────┘                   │                                                                         │
# │ │   ┌─────────────┐                   │                                                                         │
# │ │   │  MCP Client │◄──────────────────┼──► MCP Server C (e.g., Database)                                        │
# │ │   └─────────────┘                   │                                                                         │
# │ └─────────────────────────────────────┘                                                                         │
# │ ```                                                                                                             │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 6. 🧩 Key Components / Primitives                                                                            │
# │                                                                                                                 │
# │ MCP defines three core **primitives** that servers can expose:                                                  │
# │                                                                                                                 │
# │ ### 🔧 1. Tools                                                                                                 │
# │ - **Executable functions** the AI can invoke to perform actions.                                                │
# │ - Examples: run a shell command, send an email, query a database, call an API, search the web.                  │
# │ - Tools are **model-controlled** — the LLM decides when and how to call them.                                   │
# │                                                                                                                 │
# │ ### 📂 2. Resources                                                                                             │
# │ - **Data or content** that can be read and injected into the AI's context.                                      │
# │ - Examples: file contents, database records, live system data, API responses.                                   │
# │ - Resources are **application-controlled** — the host decides what to expose.                                   │
# │                                                                                                                 │
# │ ### 💬 3. Prompts                                                                                               │
# │ - **Pre-defined prompt templates or workflows** that servers can offer.                                         │
# │ - Allow servers to suggest structured interaction patterns to the AI.                                           │
# │ - Examples: a "summarize this document" prompt template, a "debug this code" workflow.                          │
# │                                                                                                                 │
# │ ### Additionally:                                                                                               │
# │ - **Sampling**: Allows MCP servers to request LLM completions back through the host, enabling complex agentic   │
# │ loops.                                                                                                          │
# │ - **Roots**: Define the boundaries/scope of what a server can access (e.g., a specific directory).              │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 7. 🚀 Use Cases                                                                                              │
# │                                                                                                                 │
# │ MCP unlocks a wide range of powerful AI integration scenarios:                                                  │
# │                                                                                                                 │
# │ | Use Case | Description |                                                                                      │
# │ |---|---|                                                                                                       │
# │ | **Code Development** | AI IDEs (like Cursor, VS Code) use MCP to give LLMs access to codebases, terminals,    │
# │ and version control (GitHub/GitLab). |                                                                          │
# │ | **Database Querying** | AI agents query SQL/NoSQL databases in natural language via MCP-connected database    │
# │ servers. |                                                                                                      │
# │ | **File System Access** | LLMs read, write, and manage local or cloud files through MCP file system servers. | │
# │ | **Web Search & Browsing** | AI assistants perform live web searches or browse URLs via MCP-connected          │
# │ search/browser tools. |                                                                                         │
# │ | **Business Tool Integration** | Connect AI to Slack, Notion, Google Drive, Jira, Salesforce, etc. |           │
# │ | **Agentic Workflows** | Multi-step AI agents that chain tool calls (e.g., research → write → save → send)     │
# │ using MCP as the backbone. |                                                                                    │
# │ | **DevOps & Cloud** | AI manages cloud infrastructure (AWS, GCP, Azure) or CI/CD pipelines via MCP servers. |  │
# │ | **Healthcare/Finance** | Securely connect AI to domain-specific databases and compliance-sensitive systems. | │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 8. 🌍 Significance in the AI/LLM Ecosystem                                                                   │
# │                                                                                                                 │
# │ MCP represents a **paradigm shift** in how AI systems are built and deployed:                                   │
# │                                                                                                                 │
# │ ### ✅ Standardization                                                                                          │
# │ It brings **HTTP-like standardization** to AI tool use — just as HTTP unified how web clients and servers       │
# │ communicate, MCP aims to unify how AI models and tools communicate.                                             │
# │                                                                                                                 │
# │ ### ✅ Interoperability                                                                                         │
# │ Any LLM that supports MCP can use **any MCP server**, regardless of who built either. This breaks down silos    │
# │ between AI providers and tool developers.                                                                       │
# │                                                                                                                 │
# │ ### ✅ Accelerating Agentic AI                                                                                  │
# │ MCP is a **foundational enabler of AI agents** — autonomous systems that take multi-step actions in the real    │
# │ world. Without a standard like MCP, building reliable agents is extremely complex.                              │
# │                                                                                                                 │
# │ ### ✅ Developer Ecosystem                                                                                      │
# │ By open-sourcing MCP, Anthropic has catalyzed a **growing ecosystem of MCP servers** — developers worldwide are │
# │ building and sharing MCP servers for hundreds of tools and services.                                            │
# │                                                                                                                 │
# │ ### ✅ Security & Control                                                                                       │
# │ MCP includes built-in concepts for **scoping, permissions, and sandboxing**, giving developers and users        │
# │ control over what AI can and cannot access.                                                                     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 9. 📈 Recent Developments & Adoption (2024–2025)                                                             │
# │                                                                                                                 │
# │ - **November 2024**: Anthropic publicly released MCP as an open standard, alongside reference implementations   │
# │ and an SDK.                                                                                                     │
# │ - **Rapid Community Adoption**: Within months, hundreds of open-source MCP servers were published on GitHub for │
# │ tools like Brave Search, PostgreSQL, Slack, GitHub, Google Drive, Puppeteer (web browsing), and more.           │
# │ - **IDE Integration**: AI-powered coding tools like **Cursor**, **Zed**, and **Codeium** adopted MCP to give    │
# │ their AI assistants richer context about codebases and development environments.                                │
# │ - **Claude Desktop**: Anthropic's own Claude Desktop app was updated to support MCP, allowing users to connect  │
# │ local MCP servers directly to Claude.                                                                           │
# │ - **Broader Industry Interest**: Other AI labs and tool providers began evaluating or adopting MCP, signaling   │
# │ its potential to become a **true industry standard** rather than just an Anthropic-specific protocol.           │
# │ - **Enterprise Uptake**: Companies began building internal MCP servers to connect Claude and other LLMs to      │
# │ proprietary databases, internal APIs, and enterprise software stacks.                                           │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 10. 🔑 Summary                                                                                               │
# │                                                                                                                 │
# │ | Attribute | Detail |                                                                                          │
# │ |---|---|                                                                                                       │
# │ | **Full Name** | Model Context Protocol (MCP) |                                                                │
# │ | **Created By** | Anthropic |                                                                                  │
# │ | **Released** | November 2024 (open source) |                                                                  │
# │ | **Type** | Open standard communication protocol |                                                             │
# │ | **Underlying Tech** | JSON-RPC over stdio or HTTP/SSE |                                                       │
# │ | **Core Architecture** | Host → Client → Server |                                                              │
# │ | **Key Primitives** | Tools, Resources, Prompts |                                                              │
# │ | **Primary Goal** | Standardize AI ↔ tool/data integration |                                                   │
# │ | **Key Benefit** | Eliminates N×M integration problem |                                                        │
# │ | **Significance** | Foundational infrastructure for agentic AI |                                               │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ## 💡 Conclusion                                                                                                │
# │                                                                                                                 │
# │ The **Model Context Protocol** is one of the most important infrastructure-level developments in the recent AI  │
# │ landscape. By providing a **universal, open standard** for connecting AI models to the tools and data they      │
# │ need, MCP dramatically lowers the barrier to building powerful, context-aware, and agentic AI applications. Its │
# │ creation by Anthropic and release as an open standard signals a maturing AI industry that increasingly          │
# │ recognizes the need for **shared infrastructure** — much like the internet needed TCP/IP and HTTP before it     │
# │ could truly flourish. As adoption grows across models, IDEs, enterprise tools, and cloud platforms, MCP is      │
# │ well-positioned to become the **backbone of the agentic AI era**.                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ ## 🔌 Model Context Protocol (MCP) — Overview                                                                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### What Is MCP?                                                                                                │
# │                                                                                                                 │
# │ The **Model Context Protocol (MCP)** is an **open standard protocol** created by **Anthropic** (released in     │
# │ November 2024) that enables AI models to seamlessly and consistently connect to external tools, data sources,   │
# │ APIs, file systems, and services. The best analogy: MCP is the **"USB-C port" for AI** — a universal connector  │
# │ that eliminates the need for one-off, custom integrations between every AI model and every tool.                │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 🎯 The Problem It Solves                                                                                    │
# │                                                                                                                 │
# │ Before MCP, connecting an AI to external tools required custom integrations for every model + tool combination  │
# │ — an unmanageable **N×M problem**. MCP collapses this into a **1×N solution**: build one MCP server for your    │
# │ tool, and any MCP-compatible AI can use it.                                                                     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 🏗️ Architecture                                                                                              │
# │                                                                                                                 │
# │ MCP follows a clean **three-tier client-server model** built on **JSON-RPC**:                                   │
# │                                                                                                                 │
# │ | Layer | Role |                                                                                                │
# │ |---|---|                                                                                                       │
# │ | **MCP Host** | The AI application the user interacts with (e.g., Claude Desktop, an IDE) |                    │
# │ | **MCP Client** | Embedded in the Host; manages protocol-level communication with servers |                    │
# │ | **MCP Server** | A lightweight service that exposes tools, data, or prompts to the AI |                       │
# │                                                                                                                 │
# │ A single Host can connect to **multiple MCP Servers simultaneously**, giving the AI access to many capabilities │
# │ at once.                                                                                                        │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 🧩 Core Primitives                                                                                          │
# │                                                                                                                 │
# │ MCP servers expose three fundamental building blocks:                                                           │
# │                                                                                                                 │
# │ 1. **🔧 Tools** — Executable functions the AI can invoke (e.g., run a query, call an API, send a message).      │
# │ *Model-controlled.*                                                                                             │
# │ 2. **📂 Resources** — Data/content injected into the AI's context (e.g., file contents, database records).      │
# │ *Application-controlled.*                                                                                       │
# │ 3. **💬 Prompts** — Pre-defined prompt templates or workflows the server can suggest to the AI.                 │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### ⚙️ How It Works                                                                                              │
# │                                                                                                                 │
# │ 1. The AI (via the MCP Client) sends a **structured JSON-RPC request** to an MCP Server.                        │
# │ 2. The MCP Server processes the request and returns a **structured response**.                                  │
# │ 3. The AI incorporates the result into its reasoning and continues.                                             │
# │                                                                                                                 │
# │ Transport options include **stdio** (for local tools) and **HTTP with Server-Sent Events** (for remote/cloud    │
# │ tools).                                                                                                         │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 🚀 Key Use Cases                                                                                            │
# │                                                                                                                 │
# │ - **AI-powered coding** — IDEs like Cursor and Zed give LLMs access to codebases, terminals, and GitHub via     │
# │ MCP.                                                                                                            │
# │ - **Database querying** — Natural language queries to SQL/NoSQL databases.                                      │
# │ - **File system access** — Reading and writing local or cloud files.                                            │
# │ - **Business tool integration** — Connecting AI to Slack, Notion, Google Drive, Jira, Salesforce, etc.          │
# │ - **Agentic workflows** — Multi-step AI agents that chain actions (research → write → save → send).             │
# │ - **DevOps & cloud management** — AI managing infrastructure or CI/CD pipelines.                                │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 🌍 Why It Matters                                                                                           │
# │                                                                                                                 │
# │ | Benefit | Description |                                                                                       │
# │ |---|---|                                                                                                       │
# │ | **Standardization** | Like HTTP for the web, MCP unifies how AI and tools communicate |                       │
# │ | **Interoperability** | Any MCP-compatible LLM works with any MCP-compatible server |                          │
# │ | **Agentic AI enablement** | Provides the foundational infrastructure for autonomous AI agents |               │
# │ | **Developer ecosystem** | Open standard has spawned hundreds of community-built MCP servers |                 │
# │ | **Security & control** | Built-in scoping, permissions, and sandboxing for safe AI access |                   │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 📈 Adoption & Ecosystem                                                                                     │
# │                                                                                                                 │
# │ Since its open-source release in **November 2024**, MCP has seen rapid growth:                                  │
# │ - **Claude Desktop** natively supports MCP for local server connections.                                        │
# │ - **AI IDEs** (Cursor, Zed, Codeium) have integrated MCP for richer development context.                        │
# │ - **Hundreds of community MCP servers** exist for tools like PostgreSQL, GitHub, Brave Search, Google Drive,    │
# │ Puppeteer, and more.                                                                                            │
# │ - **Enterprises** are building internal MCP servers to connect AI to proprietary systems.                       │
# │ - **Broader industry interest** from other AI labs signals its potential as a true cross-industry standard.     │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### 💡 Bottom Line                                                                                              │
# │                                                                                                                 │
# │ MCP is shaping up to be the **foundational infrastructure layer for the agentic AI era** — much like TCP/IP and │
# │ HTTP were for the internet. By giving AI models a standardized, secure, and extensible way to interact with the │
# │ world, it dramatically lowers the barrier to building powerful, real-world AI applications.                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Trace:
# https://smith.langchain.com/public/20183831-065c-4aad-840e-7ec0f21aa071/r/e0cf95bf-f1f7-4c82-80c0-400750407ab0
# <!-- https://smith.langchain.com/public/a349adcf-1abd-43db-92ef-60a6c4047534/r/a3aaacf9-f3e1-4bcd-bd37-ccc86d91589f -->
